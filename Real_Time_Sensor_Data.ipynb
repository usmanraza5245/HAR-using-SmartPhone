# %%
from firebase import firebase 
firebase = firebase.FirebaseApplication("https://sensors-live-stream-default-rtdb.firebaseio.com/")
result = firebase.get('Data',None)
#print(result)

# %%
gero = []
grav_accelero = []
acceleration = []
for key, val in result.items():
    #print(val)
    data = {}
    for x in val:
        data[x] = val[x]
    if data['type'] == "Accelerometer":
        grav_accelero.append(data)
    elif data['type'] == 'GyroScope':
        gero.append(data)
    else:
        acceleration.append(data)
        
#print("Accelerometer Data:", accelero)
#print(acceleration)

# %%
import pyrebase
import time
config = {
    'apiKey': "AIzaSyDT9TaIef_uI2Rx6nX6Ts8G8aZ-gS_tkg8",
    'authDomain': "sesor-2a319.firebaseapp.com",
    'databaseURL': "https://sesor-2a319-default-rtdb.europe-west1.firebasedatabase.app",
    'projectId': "sesor-2a319",
    'storageBucket': "sesor-2a319.appspot.com",
    'messagingSenderId': "990322928470",
    'appId': "1:990322928470:web:d7b3406e890dab2eaa84f7",
    'measurementId': "G-BYZ49N5019"
}


firebase = pyrebase.initialize_app(config)

db = firebase.database()

def stream_handler(message):
    print(message["event"]) # put
    print(message["path"]) # /-K7yGTTEp7O549EzTYtI
    print(message["data"]) # {'title': 'Pyrebase', "body": "etc..."}
    #print("ABCDEF")

my_stream = db.child("/sesor-2a319-default-rtdb/Data").stream(stream_handler,None)
time.sleep(10)
print(my_stream)

data = db.child('Data').get()
# Out:
# put
# /
# None
# ...

# %%
print(data.val())
# Out:
# OrderedDict([('-MR7QWzX2svlR46fCpsH', {'sensorType': 'Accelerometer', 'val1': 0.06199999898672104, 'val2': -0.2160000056028366, 'val3': 9.928999900817871}), ('-MR7QWzw1w0_mYvregXr', {'sensorType': 'Body_Acceleration', 'val1': -7.79840087890625, 'val2': -8.020800590515137, 'val3': 0.0951995849609375}), ('-MR7QX-0J3J_OVtggzSL', {'sensorType': 'Accelerometer', 'val1': 0.020999999716877937, 'val2': -0.20900000631809235, 'val3': 9.944999694824219}), ('-MR7QX-2k-evBsMpvM1f', {'sensorType': 'Body_Acceleration', 'val1': -7.83120059967041, 'val2': -8.0152006149292, 'val3': 0.10799980163574219}), ('-MR7QX-6pMOpIN-QAcj5', {'sensorType': 'GyroScope', 'val1': -0.0005080000264570117, 'val2': 0.0008720000041648746, 'val3': 0.0008720000041648746}), ('-MR7QX-Bs3UGPDBOTZPr', {'sensorType': 'GyroScope', 'val1': -0.0005080000264570117, 'val2': 0.0008720000041648746, 'val3': 0.0008720000041648746}), ('-MR7QX-IPjbko7aoNozM', {'sensorType': 'Accelerometer', 'val1': 0.08100000023841858, 'val2': -0.171000003
# ...

# %%
from firebase import firebase
firebase = firebase.FirebaseApplication("https://sesor-2a319-default-rtdb.europe-west1.firebasedatabase.app/", None)
result = firebase.get('/Data','')
#print(result)
list = []
dict = {}

for key, value in result.items():
    list.append(value)

print(result)

# %%
import requests
from requests.packages import urllib3
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db

#event listener:
def listener(event):
    print(event.event_type)
    print(event.path)
    print(event.data)

json_path = '/home/da-emon/Documents/Fyp/jasonkey.json'
xyz = {
    'apiKey': "AIzaSyDT9TaIef_uI2Rx6nX6Ts8G8aZ-gS_tkg8",
    'authDomain': "sesor-2a319.firebaseapp.com",
    'databaseURL': "https://sesor-2a319-default-rtdb.europe-west1.firebasedatabase.app",
    'projectId': "sesor-2a319",
    'storageBucket': "sesor-2a319.appspot.com",
    'messagingSenderId': "990322928470",
    'appId': "1:990322928470:web:d7b3406e890dab2eaa84f7",
    'measurementId': "G-BYZ49N5019"
}
app_name = 'Real_Time_Sensor_Data'
if app_name not in firebase_admin._apps:
    cred = credentials.Certificate(json_path)
    firebase_admin.initialize_app(cred,xyz)

firebase_admin.db.reference('/sesor-2a319-default-rtdb/Data/').listen(listener)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-1e7d891c8ba1> in <module>
#      27     firebase_admin.initialize_app(cred,xyz)
#      28
# ---> 29 firebase_admin.db.reference('/sesor-2a319-default-rtdb/Data/').listen(listener)
#
# ~/anaconda3/lib/python3.8/site-packages/firebase_admin/db.py in reference(path, app, url)
#      67       ValueError: If the specified path or app is invalid.
#      68     """
# ---> 69     service = _utils.get_app_service(app, _DB_ATTRIBUTE, _DatabaseService)
#      70     client = service.get_client(url)
#      71     return Reference(client=client, path=path)
#
# ~/anaconda3/lib/python3.8/site-packages/firebase_admin/_utils.py in get_app_service(app, name, initializer)
#      99 def get_app_service(app, name, initializer):
#     100     app = _get_initialized_app(app)
# ...

# %%
import requests
from requests.packages import urllib3
print(urllib3.__version__)
